# %%
import requests
import pandas as pd
from datetime import datetime

# %%
api_key = 'd43dc4925a3e4baaac1192710251409'
baseurl = 'http://api.weatherapi.com/v1'
# f "http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
city = 'Louisville'

# %%
response = requests.get(f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}")
response.status_code
# Out:
# 200

# %%
# Building a summary for the city and saving into a dictionary
# get a current weather and saving summary into a dictionary

def get_city_data(city, api_key):
    current_weather_url = f"{baseurl}/current.json?key={api_key}&q={city}"
    current_weather_response = requests.get(current_weather_url)
    if response.status_code == 200:
        data = current_weather_response.json()
        current = data['current']
        location = data['location']
        temp_f = current['temp_f']
        wind_mph = current['wind_mph']
        humidity = current['humidity']

        print('Summary of the City:')
        print(f" Weather for {location['name']}, {location['region']} ")
        print(f" Temperature: {current['temp_f']} °F /  {current['temp_c']}  °C")
        print(f" Condition: {current['condition']['text']}")
        print(f" Humidity: {current['humidity']}%")
        print(f" Wind Speed {current['wind_mph']} mph / {current['wind_kph']} kph")
        print(f" Last Update: {current['last_updated']}")
        city_summary_dictionary = {
            'city_name': location['name'],
            'region': location['region'],
            'country': location['country'],
            'temperature_c': current['temp_c'],
            'temperature_f': current['temp_f'],
            'condition': current ['condition']['text'],
            'humidity': current['humidity'],
            'wind_kph': current['wind_kph'],
            'last_updated': location['localtime']}
    
        return city_summary_dictionary

    else:
        print(f"Error fetching data for {city}:{response.status_code}")

        

summary = get_city_data(city, api_key)


print(summary)
# Out:
# Summary of the City:
#  Weather for Louisville, Kentucky
#  Temperature: 75.0 °F /  23.9  °C
#  Condition: Partly cloudy
#  Humidity: 79%
#  Wind Speed 2.2 mph / 3.6 kph
#  Last Update: 2025-09-23 23:15
# {'city_name': 'Louisville', 'region': 'Kentucky', 'country': 'United States of America', 'temperature_c': 23.9, 'temperature_f': 75.0, 'condition': 'Partly cloudy', 'humidity': 79, 'wind_kph': 3.6, 'last_updated': '2025-09-23 23:17'}

# %%
get_city_data(city, api_key)
# Out:
# Summary of the City:
#  Weather for Louisville, Kentucky
#  Temperature: 75.0 °F /  23.9  °C
#  Condition: Partly cloudy
#  Humidity: 79%
#  Wind Speed 2.2 mph / 3.6 kph
#  Last Update: 2025-09-23 23:15
# {'city_name': 'Louisville',
#  'region': 'Kentucky',
#  'country': 'United States of America',
#  'temperature_c': 23.9,
#  'temperature_f': 75.0,
#  'condition': 'Partly cloudy',
#  'humidity': 79,
#  'wind_kph': 3.6,
#  'last_updated': '2025-09-23 23:17'}

# %%
# get the forecast

forecast_url = f"{baseurl}/forecast.json?key={api_key}&q={city}&days=7"
forecast_response = requests.get(forecast_url)
forecast_response.status_code
forecast_data = forecast_response.json()
forecast = forecast_data['forecast']['forecastday']
forecast
# Out:
# [{'date': '2025-09-23',
#   'date_epoch': 1758585600,
#   'day': {'maxtemp_c': 29.7,
#    'maxtemp_f': 85.5,
#    'mintemp_c': 20.0,
#    'mintemp_f': 68.0,
#    'avgtemp_c': 23.3,
#    'avgtemp_f': 74.0,
#    'maxwind_mph': 6.3,
#    'maxwind_kph': 10.1,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 6.2,
#    'avgvis_miles': 3.0,
#    'avghumidity': 86,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': 0,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Partly Cloudy ',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#     'code': 1003},
#    'uv': 1.4},
#   'astro': {'sunrise': '07:32 AM',
#    'sunset': '07:38 PM',
#    'moonrise': '09:17 AM',
#    'moonset': '08:18 PM',
#    'moon_phase': 'Waxing Crescent',
#    'moon_illumination': 1,
#    'is_moon_up': 0,
#    'is_sun_up': 0},
#   'hour': [{'time_epoch': 1758600000,
#     'time': '2025-09-23 00:00',
#     'temp_c': 20.3,
#     'temp_f': 68.6,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 195,
#     'wind_dir': 'SSW',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.45,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 91,
#     'cloud': 3,
#     'feelslike_c': 20.3,
#     'feelslike_f': 68.6,
#     'windchill_c': 20.3,
#     'windchill_f': 68.6,
#     'heatindex_c': 20.7,
#     'heatindex_f': 69.2,
#     'dewpoint_c': 18.6,
#     'dewpoint_f': 65.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 8.4,
#     'gust_kph': 13.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758603600,
#     'time': '2025-09-23 01:00',
#     'temp_c': 21.0,
#     'temp_f': 69.7,
#     'is_day': 0,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 190,
#     'wind_dir': 'S',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.46,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 93,
#     'cloud': 100,
#     'feelslike_c': 21.0,
#     'feelslike_f': 69.7,
#     'windchill_c': 21.0,
#     'windchill_f': 69.7,
#     'heatindex_c': 22.5,
#     'heatindex_f': 72.5,
#     'dewpoint_c': 18.9,
#     'dewpoint_f': 65.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 8.3,
#     'gust_kph': 13.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758607200,
#     'time': '2025-09-23 02:00',
#     'temp_c': 21.2,
#     'temp_f': 70.2,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 197,
#     'wind_dir': 'SSW',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.46,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 92,
#     'cloud': 58,
#     'feelslike_c': 21.2,
#     'feelslike_f': 70.2,
#     'windchill_c': 21.2,
#     'windchill_f': 70.2,
#     'heatindex_c': 23.4,
#     'heatindex_f': 74.1,
#     'dewpoint_c': 20.2,
#     'dewpoint_f': 68.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 8.0,
#     'gust_kph': 12.8,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758610800,
#     'time': '2025-09-23 03:00',
#     'temp_c': 21.2,
#     'temp_f': 70.1,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 196,
#     'wind_dir': 'SSW',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.44,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 93,
#     'cloud': 46,
#     'feelslike_c': 21.2,
#     'feelslike_f': 70.1,
#     'windchill_c': 21.2,
#     'windchill_f': 70.1,
#     'heatindex_c': 23.8,
#     'heatindex_f': 74.8,
#     'dewpoint_c': 20.3,
#     'dewpoint_f': 68.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 6.8,
#     'gust_kph': 10.9,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758614400,
#     'time': '2025-09-23 04:00',
#     'temp_c': 20.9,
#     'temp_f': 69.6,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 207,
#     'wind_dir': 'SSW',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.43,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 92,
#     'cloud': 36,
#     'feelslike_c': 20.9,
#     'feelslike_f': 69.6,
#     'windchill_c': 20.9,
#     'windchill_f': 69.6,
#     'heatindex_c': 22.2,
#     'heatindex_f': 71.9,
#     'dewpoint_c': 19.8,
#     'dewpoint_f': 67.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 6.0,
#     'gust_kph': 9.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758618000,
#     'time': '2025-09-23 05:00',
#     'temp_c': 20.8,
#     'temp_f': 69.4,
#     'is_day': 0,
#     'condition': {'text': 'Mist',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#      'code': 1030},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 213,
#     'wind_dir': 'SSW',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.43,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 94,
#     'cloud': 32,
#     'feelslike_c': 20.8,
#     'feelslike_f': 69.4,
#     'windchill_c': 20.8,
#     'windchill_f': 69.4,
#     'heatindex_c': 21.4,
#     'heatindex_f': 70.6,
#     'dewpoint_c': 19.7,
#     'dewpoint_f': 67.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 6.3,
#     'gust_kph': 10.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758621600,
#     'time': '2025-09-23 06:00',
#     'temp_c': 20.7,
#     'temp_f': 69.3,
#     'is_day': 0,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 239,
#     'wind_dir': 'WSW',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.45,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 94,
#     'cloud': 98,
#     'feelslike_c': 20.7,
#     'feelslike_f': 69.3,
#     'windchill_c': 20.7,
#     'windchill_f': 69.3,
#     'heatindex_c': 21.0,
#     'heatindex_f': 69.8,
#     'dewpoint_c': 19.7,
#     'dewpoint_f': 67.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 5.3,
#     'gust_kph': 8.5,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758625200,
#     'time': '2025-09-23 07:00',
#     'temp_c': 20.4,
#     'temp_f': 68.8,
#     'is_day': 0,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 194,
#     'wind_dir': 'SSW',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.48,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 93,
#     'cloud': 100,
#     'feelslike_c': 20.4,
#     'feelslike_f': 68.8,
#     'windchill_c': 20.4,
#     'windchill_f': 68.8,
#     'heatindex_c': 20.6,
#     'heatindex_f': 69.1,
#     'dewpoint_c': 19.4,
#     'dewpoint_f': 67.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 6.0,
#     'gust_kph': 9.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758628800,
#     'time': '2025-09-23 08:00',
#     'temp_c': 20.7,
#     'temp_f': 69.3,
#     'is_day': 1,
#     'condition': {'text': 'Fog',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/248.png',
#      'code': 1135},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 188,
#     'wind_dir': 'S',
#     'pressure_mb': 999.0,
#     'pressure_in': 29.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 97,
#     'cloud': 100,
#     'feelslike_c': 20.7,
#     'feelslike_f': 69.3,
#     'windchill_c': 20.7,
#     'windchill_f': 69.3,
#     'heatindex_c': 20.8,
#     'heatindex_f': 69.4,
#     'dewpoint_c': 19.7,
#     'dewpoint_f': 67.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 6.9,
#     'gust_kph': 11.1,
#     'uv': 0.0,
#     'short_rad': 0.99,
#     'diff_rad': 0.52,
#     'dni': 0.66,
#     'gti': 0.62},
#    {'time_epoch': 1758632400,
#     'time': '2025-09-23 09:00',
#     'temp_c': 21.3,
#     'temp_f': 70.3,
#     'is_day': 1,
#     'condition': {'text': 'Mist',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/143.png',
#      'code': 1030},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 209,
#     'wind_dir': 'SSW',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.48,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 95,
#     'cloud': 57,
#     'feelslike_c': 21.3,
#     'feelslike_f': 70.3,
#     'windchill_c': 21.3,
#     'windchill_f': 70.3,
#     'heatindex_c': 22.6,
#     'heatindex_f': 72.7,
#     'dewpoint_c': 20.2,
#     'dewpoint_f': 68.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 5.0,
#     'vis_miles': 3.0,
#     'gust_mph': 5.3,
#     'gust_kph': 8.5,
#     'uv': 0.5,
#     'short_rad': 113.44,
#     'diff_rad': 47.21,
#     'dni': 85.72,
#     'gti': 63.9},
#    {'time_epoch': 1758636000,
#     'time': '2025-09-23 10:00',
#     'temp_c': 21.9,
#     'temp_f': 71.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 4.9,
#     'wind_kph': 7.9,
#     'wind_degree': 219,
#     'wind_dir': 'SW',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.49,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 93,
#     'cloud': 53,
#     'feelslike_c': 21.9,
#     'feelslike_f': 71.4,
#     'windchill_c': 21.9,
#     'windchill_f': 71.4,
#     'heatindex_c': 23.7,
#     'heatindex_f': 74.7,
#     'dewpoint_c': 20.6,
#     'dewpoint_f': 69.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.1,
#     'gust_kph': 9.8,
#     'uv': 1.5,
#     'short_rad': 205.28,
#     'diff_rad': 70.44,
#     'dni': 173.48,
#     'gti': 106.59},
#    {'time_epoch': 1758639600,
#     'time': '2025-09-23 11:00',
#     'temp_c': 22.3,
#     'temp_f': 72.2,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 206,
#     'wind_dir': 'SSW',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.46,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 93,
#     'cloud': 74,
#     'feelslike_c': 24.4,
#     'feelslike_f': 75.9,
#     'windchill_c': 22.3,
#     'windchill_f': 72.2,
#     'heatindex_c': 24.4,
#     'heatindex_f': 75.9,
#     'dewpoint_c': 21.2,
#     'dewpoint_f': 70.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.4,
#     'gust_kph': 10.2,
#     'uv': 3.2,
#     'short_rad': 296.92,
#     'diff_rad': 85.57,
#     'dni': 290.07,
#     'gti': 144.22},
#    {'time_epoch': 1758643200,
#     'time': '2025-09-23 12:00',
#     'temp_c': 23.3,
#     'temp_f': 73.9,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 217,
#     'wind_dir': 'SW',
#     'pressure_mb': 999.0,
#     'pressure_in': 29.51,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 90,
#     'cloud': 97,
#     'feelslike_c': 25.4,
#     'feelslike_f': 77.8,
#     'windchill_c': 23.3,
#     'windchill_f': 73.9,
#     'heatindex_c': 25.4,
#     'heatindex_f': 77.8,
#     'dewpoint_c': 21.0,
#     'dewpoint_f': 69.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.4,
#     'gust_kph': 10.4,
#     'uv': 4.9,
#     'short_rad': 374.54,
#     'diff_rad': 106.14,
#     'dni': 426.01,
#     'gti': 180.47},
#    {'time_epoch': 1758646800,
#     'time': '2025-09-23 13:00',
#     'temp_c': 24.7,
#     'temp_f': 76.5,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 222,
#     'wind_dir': 'SW',
#     'pressure_mb': 999.0,
#     'pressure_in': 29.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 88,
#     'cloud': 77,
#     'feelslike_c': 27.2,
#     'feelslike_f': 81.0,
#     'windchill_c': 24.7,
#     'windchill_f': 76.5,
#     'heatindex_c': 27.2,
#     'heatindex_f': 81.0,
#     'dewpoint_c': 22.0,
#     'dewpoint_f': 71.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 6.0,
#     'short_rad': 436.61,
#     'diff_rad': 126.5,
#     'dni': 635.14,
#     'gti': 211.22},
#    {'time_epoch': 1758650400,
#     'time': '2025-09-23 14:00',
#     'temp_c': 26.3,
#     'temp_f': 79.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 229,
#     'wind_dir': 'SW',
#     'pressure_mb': 999.0,
#     'pressure_in': 29.49,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 81,
#     'cloud': 30,
#     'feelslike_c': 29.2,
#     'feelslike_f': 84.5,
#     'windchill_c': 26.3,
#     'windchill_f': 79.4,
#     'heatindex_c': 29.2,
#     'heatindex_f': 84.5,
#     'dewpoint_c': 22.8,
#     'dewpoint_f': 73.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.0,
#     'gust_kph': 11.2,
#     'uv': 6.0,
#     'short_rad': 477.82,
#     'diff_rad': 149.28,
#     'dni': 1049.97,
#     'gti': 235.59},
#    {'time_epoch': 1758654000,
#     'time': '2025-09-23 15:00',
#     'temp_c': 26.9,
#     'temp_f': 80.4,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 233,
#     'wind_dir': 'SW',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.46,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 73,
#     'cloud': 45,
#     'feelslike_c': 29.4,
#     'feelslike_f': 85.0,
#     'windchill_c': 26.9,
#     'windchill_f': 80.4,
#     'heatindex_c': 29.4,
#     'heatindex_f': 85.0,
#     'dewpoint_c': 22.7,
#     'dewpoint_f': 72.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.2,
#     'gust_kph': 9.9,
#     'uv': 5.2,
#     'short_rad': 649.86,
#     'diff_rad': 262.45,
#     'dni': 3341.38,
#     'gti': 344.97},
#    {'time_epoch': 1758657600,
#     'time': '2025-09-23 16:00',
#     'temp_c': 28.3,
#     'temp_f': 82.9,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 230,
#     'wind_dir': 'SW',
#     'pressure_mb': 999.0,
#     'pressure_in': 29.49,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 67,
#     'cloud': 46,
#     'feelslike_c': 31.6,
#     'feelslike_f': 88.9,
#     'windchill_c': 28.3,
#     'windchill_f': 82.9,
#     'heatindex_c': 31.6,
#     'heatindex_f': 88.9,
#     'dewpoint_c': 20.9,
#     'dewpoint_f': 69.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.0,
#     'gust_kph': 11.2,
#     'uv': 3.8,
#     'short_rad': 619.66,
#     'diff_rad': 243.18,
#     'dni': 0.0,
#     'gti': 230.37},
#    {'time_epoch': 1758661200,
#     'time': '2025-09-23 17:00',
#     'temp_c': 27.8,
#     'temp_f': 82.0,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 233,
#     'wind_dir': 'SW',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.48,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 67,
#     'cloud': 13,
#     'feelslike_c': 30.7,
#     'feelslike_f': 87.2,
#     'windchill_c': 27.8,
#     'windchill_f': 82.0,
#     'heatindex_c': 30.7,
#     'heatindex_f': 87.2,
#     'dewpoint_c': 23.0,
#     'dewpoint_f': 73.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.6,
#     'gust_kph': 12.2,
#     'uv': 2.1,
#     'short_rad': 573.48,
#     'diff_rad': 214.01,
#     'dni': 0.0,
#     'gti': 203.35},
#    {'time_epoch': 1758664800,
#     'time': '2025-09-23 18:00',
#     'temp_c': 27.4,
#     'temp_f': 81.2,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 226,
#     'wind_dir': 'SW',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.45,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 71,
#     'cloud': 19,
#     'feelslike_c': 30.2,
#     'feelslike_f': 86.4,
#     'windchill_c': 27.4,
#     'windchill_f': 81.2,
#     'heatindex_c': 30.2,
#     'heatindex_f': 86.4,
#     'dewpoint_c': 21.5,
#     'dewpoint_f': 70.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.3,
#     'gust_kph': 11.8,
#     'uv': 0.8,
#     'short_rad': 500.36,
#     'diff_rad': 193.17,
#     'dni': 0.0,
#     'gti': 183.17},
#    {'time_epoch': 1758668400,
#     'time': '2025-09-23 19:00',
#     'temp_c': 26.2,
#     'temp_f': 79.2,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 223,
#     'wind_dir': 'SW',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.45,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 77,
#     'cloud': 3,
#     'feelslike_c': 28.7,
#     'feelslike_f': 83.6,
#     'windchill_c': 26.2,
#     'windchill_f': 79.2,
#     'heatindex_c': 28.7,
#     'heatindex_f': 83.6,
#     'dewpoint_c': 22.6,
#     'dewpoint_f': 72.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.8,
#     'gust_kph': 11.0,
#     'uv': 0.1,
#     'short_rad': 414.5,
#     'diff_rad': 162.22,
#     'dni': 0.0,
#     'gti': 153.71},
#    {'time_epoch': 1758672000,
#     'time': '2025-09-23 20:00',
#     'temp_c': 25.4,
#     'temp_f': 77.7,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.5,
#     'wind_kph': 4.0,
#     'wind_degree': 221,
#     'wind_dir': 'SW',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.46,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 79,
#     'cloud': 7,
#     'feelslike_c': 27.6,
#     'feelslike_f': 81.7,
#     'windchill_c': 25.4,
#     'windchill_f': 77.7,
#     'heatindex_c': 27.6,
#     'heatindex_f': 81.7,
#     'dewpoint_c': 21.2,
#     'dewpoint_f': 70.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.2,
#     'gust_kph': 8.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758675600,
#     'time': '2025-09-23 21:00',
#     'temp_c': 24.7,
#     'temp_f': 76.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.2,
#     'wind_kph': 3.6,
#     'wind_degree': 185,
#     'wind_dir': 'S',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.46,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 81,
#     'cloud': 3,
#     'feelslike_c': 26.9,
#     'feelslike_f': 80.4,
#     'windchill_c': 24.7,
#     'windchill_f': 76.5,
#     'heatindex_c': 26.9,
#     'heatindex_f': 80.4,
#     'dewpoint_c': 21.1,
#     'dewpoint_f': 69.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 4.6,
#     'gust_kph': 7.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758679200,
#     'time': '2025-09-23 22:00',
#     'temp_c': 23.6,
#     'temp_f': 74.4,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 296,
#     'wind_dir': 'WNW',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.48,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 85,
#     'cloud': 0,
#     'feelslike_c': 25.9,
#     'feelslike_f': 78.6,
#     'windchill_c': 23.6,
#     'windchill_f': 74.4,
#     'heatindex_c': 25.9,
#     'heatindex_f': 78.6,
#     'dewpoint_c': 21.4,
#     'dewpoint_f': 70.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.9,
#     'gust_kph': 14.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758682800,
#     'time': '2025-09-23 23:00',
#     'temp_c': 23.9,
#     'temp_f': 75.0,
#     'is_day': 0,
#     'condition': {'text': 'Partly cloudy',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 2.2,
#     'wind_kph': 3.6,
#     'wind_degree': 344,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1014.0,
#     'pressure_in': 29.95,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 79,
#     'cloud': 50,
#     'feelslike_c': 25.3,
#     'feelslike_f': 77.6,
#     'windchill_c': 23.0,
#     'windchill_f': 73.4,
#     'heatindex_c': 25.3,
#     'heatindex_f': 77.6,
#     'dewpoint_c': 21.3,
#     'dewpoint_f': 70.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 16.0,
#     'vis_miles': 9.0,
#     'gust_mph': 3.1,
#     'gust_kph': 4.9,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0}]},
#  {'date': '2025-09-24',
#   'date_epoch': 1758672000,
#   'day': {'maxtemp_c': 25.0,
#    'maxtemp_f': 77.0,
#    'mintemp_c': 21.0,
#    'mintemp_f': 69.7,
#    'avgtemp_c': 22.5,
#    'avgtemp_f': 72.5,
#    'maxwind_mph': 6.3,
#    'maxwind_kph': 10.1,
#    'totalprecip_mm': 0.48,
#    'totalprecip_in': 0.02,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 6.7,
#    'avgvis_miles': 4.0,
#    'avghumidity': 87,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': 78,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Patchy rain nearby',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#     'code': 1063},
#    'uv': 1.0},
#   'astro': {'sunrise': '07:33 AM',
#    'sunset': '07:37 PM',
#    'moonrise': '10:17 AM',
#    'moonset': '08:43 PM',
#    'moon_phase': 'Waxing Crescent',
#    'moon_illumination': 4,
#    'is_moon_up': 1,
#    'is_sun_up': 0},
#   'hour': [{'time_epoch': 1758686400,
#     'time': '2025-09-24 00:00',
#     'temp_c': 22.6,
#     'temp_f': 72.7,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 179,
#     'wind_dir': 'S',
#     'pressure_mb': 999.0,
#     'pressure_in': 29.49,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 93,
#     'cloud': 33,
#     'feelslike_c': 25.0,
#     'feelslike_f': 77.0,
#     'windchill_c': 22.6,
#     'windchill_f': 72.7,
#     'heatindex_c': 25.0,
#     'heatindex_f': 77.0,
#     'dewpoint_c': 21.2,
#     'dewpoint_f': 70.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.7,
#     'gust_kph': 12.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758690000,
#     'time': '2025-09-24 01:00',
#     'temp_c': 22.4,
#     'temp_f': 72.3,
#     'is_day': 0,
#     'condition': {'text': 'Mist',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#      'code': 1030},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 164,
#     'wind_dir': 'SSE',
#     'pressure_mb': 999.0,
#     'pressure_in': 29.49,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 95,
#     'cloud': 11,
#     'feelslike_c': 24.9,
#     'feelslike_f': 76.8,
#     'windchill_c': 22.4,
#     'windchill_f': 72.3,
#     'heatindex_c': 24.9,
#     'heatindex_f': 76.8,
#     'dewpoint_c': 21.3,
#     'dewpoint_f': 70.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.0,
#     'gust_kph': 11.2,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758693600,
#     'time': '2025-09-24 02:00',
#     'temp_c': 22.2,
#     'temp_f': 72.0,
#     'is_day': 0,
#     'condition': {'text': 'Mist',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#      'code': 1030},
#     'wind_mph': 5.8,
#     'wind_kph': 9.4,
#     'wind_degree': 179,
#     'wind_dir': 'S',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.48,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 96,
#     'cloud': 55,
#     'feelslike_c': 24.8,
#     'feelslike_f': 76.6,
#     'windchill_c': 22.2,
#     'windchill_f': 72.0,
#     'heatindex_c': 24.8,
#     'heatindex_f': 76.6,
#     'dewpoint_c': 21.5,
#     'dewpoint_f': 70.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.8,
#     'gust_kph': 17.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758697200,
#     'time': '2025-09-24 03:00',
#     'temp_c': 22.1,
#     'temp_f': 71.7,
#     'is_day': 0,
#     'condition': {'text': 'Mist',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#      'code': 1030},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 159,
#     'wind_dir': 'SSE',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.46,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 96,
#     'cloud': 14,
#     'feelslike_c': 24.6,
#     'feelslike_f': 76.3,
#     'windchill_c': 22.1,
#     'windchill_f': 71.7,
#     'heatindex_c': 24.6,
#     'heatindex_f': 76.3,
#     'dewpoint_c': 21.4,
#     'dewpoint_f': 70.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.5,
#     'gust_kph': 15.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758700800,
#     'time': '2025-09-24 04:00',
#     'temp_c': 21.9,
#     'temp_f': 71.5,
#     'is_day': 0,
#     'condition': {'text': 'Mist',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#      'code': 1030},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 158,
#     'wind_dir': 'SSE',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.47,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 95,
#     'cloud': 16,
#     'feelslike_c': 21.9,
#     'feelslike_f': 71.5,
#     'windchill_c': 21.9,
#     'windchill_f': 71.5,
#     'heatindex_c': 24.5,
#     'heatindex_f': 76.2,
#     'dewpoint_c': 21.1,
#     'dewpoint_f': 69.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 8.4,
#     'gust_kph': 13.5,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758704400,
#     'time': '2025-09-24 05:00',
#     'temp_c': 21.8,
#     'temp_f': 71.3,
#     'is_day': 0,
#     'condition': {'text': 'Mist',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#      'code': 1030},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 167,
#     'wind_dir': 'SSE',
#     'pressure_mb': 998.0,
#     'pressure_in': 29.46,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 96,
#     'cloud': 8,
#     'feelslike_c': 21.8,
#     'feelslike_f': 71.3,
#     'windchill_c': 21.8,
#     'windchill_f': 71.3,
#     'heatindex_c': 24.5,
#     'heatindex_f': 76.0,
#     'dewpoint_c': 21.1,
#     'dewpoint_f': 69.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 6.8,
#     'gust_kph': 10.9,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758708000,
#     'time': '2025-09-24 06:00',
#     'temp_c': 21.8,
#     'temp_f': 71.2,
#     'is_day': 0,
#     'condition': {'text': 'Mist',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/143.png',
#      'code': 1030},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 170,
#     'wind_dir': 'S',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.45,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 96,
#     'cloud': 9,
#     'feelslike_c': 21.8,
#     'feelslike_f': 71.2,
#     'windchill_c': 21.8,
#     'windchill_f': 71.2,
#     'heatindex_c': 24.4,
#     'heatindex_f': 76.0,
#     'dewpoint_c': 21.0,
#     'dewpoint_f': 69.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 6.6,
#     'gust_kph': 10.7,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758711600,
#     'time': '2025-09-24 07:00',
#     'temp_c': 21.7,
#     'temp_f': 71.0,
#     'is_day': 0,
#     'condition': {'text': 'Fog',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/248.png',
#      'code': 1135},
#     'wind_mph': 4.9,
#     'wind_kph': 7.9,
#     'wind_degree': 170,
#     'wind_dir': 'S',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.45,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 97,
#     'cloud': 100,
#     'feelslike_c': 21.7,
#     'feelslike_f': 71.0,
#     'windchill_c': 21.7,
#     'windchill_f': 71.0,
#     'heatindex_c': 24.4,
#     'heatindex_f': 75.9,
#     'dewpoint_c': 21.2,
#     'dewpoint_f': 70.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 7.7,
#     'gust_kph': 12.5,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758715200,
#     'time': '2025-09-24 08:00',
#     'temp_c': 21.7,
#     'temp_f': 71.0,
#     'is_day': 1,
#     'condition': {'text': 'Fog',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/248.png',
#      'code': 1135},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 187,
#     'wind_dir': 'S',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.44,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 97,
#     'cloud': 100,
#     'feelslike_c': 21.7,
#     'feelslike_f': 71.0,
#     'windchill_c': 21.7,
#     'windchill_f': 71.0,
#     'heatindex_c': 24.4,
#     'heatindex_f': 75.9,
#     'dewpoint_c': 21.2,
#     'dewpoint_f': 70.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 7.9,
#     'gust_kph': 12.8,
#     'uv': 0.0,
#     'short_rad': 0.45,
#     'diff_rad': 0.22,
#     'dni': 0.32,
#     'gti': 0.27},
#    {'time_epoch': 1758718800,
#     'time': '2025-09-24 09:00',
#     'temp_c': 22.9,
#     'temp_f': 73.2,
#     'is_day': 1,
#     'condition': {'text': 'Mist',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/143.png',
#      'code': 1030},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 203,
#     'wind_dir': 'SSW',
#     'pressure_mb': 997.0,
#     'pressure_in': 29.45,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 96,
#     'cloud': 92,
#     'feelslike_c': 25.3,
#     'feelslike_f': 77.5,
#     'windchill_c': 22.9,
#     'windchill_f': 73.2,
#     'heatindex_c': 25.3,
#     'heatindex_f': 77.5,
#     'dewpoint_c': 21.0,
#     'dewpoint_f': 69.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 7.5,
#     'gust_kph': 12.0,
#     'uv': 0.4,
#     'short_rad': 94.68,
#     'diff_rad': 46.98,
#     'dni': 62.05,
#     'gti': 57.55},
#    {'time_epoch': 1758722400,
#     'time': '2025-09-24 10:00',
#     'temp_c': 23.1,
#     'temp_f': 73.6,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 218,
#     'wind_dir': 'SW',
#     'pressure_mb': 999.0,
#     'pressure_in': 29.5,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 83,
#     'cloud': 70,
#     'feelslike_c': 25.3,
#     'feelslike_f': 77.6,
#     'windchill_c': 23.1,
#     'windchill_f': 73.6,
#     'heatindex_c': 25.3,
#     'heatindex_f': 77.6,
#     'dewpoint_c': 21.1,
#     'dewpoint_f': 70.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 0.0,
#     'vis_miles': 0.0,
#     'gust_mph': 8.0,
#     'gust_kph': 12.9,
#     'uv': 0.1,
#     'short_rad': 52.62,
#     'diff_rad': 27.54,
#     'dni': 32.45,
#     'gti': 32.85},
#    {'time_epoch': 1758726000,
#     'time': '2025-09-24 11:00',
#     'temp_c': 22.5,
#     'temp_f': 72.5,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 243,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1001.0,
#     'pressure_in': 29.56,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 85,
#     'cloud': 92,
#     'feelslike_c': 24.9,
#     'feelslike_f': 76.8,
#     'windchill_c': 22.5,
#     'windchill_f': 72.5,
#     'heatindex_c': 24.9,
#     'heatindex_f': 76.8,
#     'dewpoint_c': 20.7,
#     'dewpoint_f': 69.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.0,
#     'gust_kph': 12.9,
#     'uv': 1.5,
#     'short_rad': 88.0,
#     'diff_rad': 48.42,
#     'dni': 54.68,
#     'gti': 56.32},
#    {'time_epoch': 1758729600,
#     'time': '2025-09-24 12:00',
#     'temp_c': 21.8,
#     'temp_f': 71.3,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 5.8,
#     'wind_kph': 9.4,
#     'wind_degree': 251,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1003.0,
#     'pressure_in': 29.62,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 88,
#     'cloud': 100,
#     'feelslike_c': 21.8,
#     'feelslike_f': 71.3,
#     'windchill_c': 21.8,
#     'windchill_f': 71.3,
#     'heatindex_c': 24.6,
#     'heatindex_f': 76.2,
#     'dewpoint_c': 19.9,
#     'dewpoint_f': 67.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.2,
#     'gust_kph': 11.5,
#     'uv': 2.5,
#     'short_rad': 130.62,
#     'diff_rad': 74.38,
#     'dni': 89.97,
#     'gti': 84.99},
#    {'time_epoch': 1758733200,
#     'time': '2025-09-24 13:00',
#     'temp_c': 21.7,
#     'temp_f': 71.1,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 248,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1005.0,
#     'pressure_in': 29.68,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 89,
#     'cloud': 100,
#     'feelslike_c': 21.7,
#     'feelslike_f': 71.1,
#     'windchill_c': 21.7,
#     'windchill_f': 71.1,
#     'heatindex_c': 24.5,
#     'heatindex_f': 76.0,
#     'dewpoint_c': 19.2,
#     'dewpoint_f': 66.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.7,
#     'gust_kph': 12.3,
#     'uv': 5.2,
#     'short_rad': 209.22,
#     'diff_rad': 106.03,
#     'dni': 213.59,
#     'gti': 127.57},
#    {'time_epoch': 1758736800,
#     'time': '2025-09-24 14:00',
#     'temp_c': 22.9,
#     'temp_f': 73.2,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 247,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1007.0,
#     'pressure_in': 29.74,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 83,
#     'cloud': 100,
#     'feelslike_c': 25.1,
#     'feelslike_f': 77.1,
#     'windchill_c': 22.9,
#     'windchill_f': 73.2,
#     'heatindex_c': 25.1,
#     'heatindex_f': 77.1,
#     'dewpoint_c': 18.5,
#     'dewpoint_f': 65.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.7,
#     'gust_kph': 12.3,
#     'uv': 5.2,
#     'short_rad': 263.89,
#     'diff_rad': 130.34,
#     'dni': 434.2,
#     'gti': 157.07},
#    {'time_epoch': 1758740400,
#     'time': '2025-09-24 15:00',
#     'temp_c': 23.9,
#     'temp_f': 75.1,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 255,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1009.0,
#     'pressure_in': 29.8,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 69,
#     'cloud': 35,
#     'feelslike_c': 25.7,
#     'feelslike_f': 78.3,
#     'windchill_c': 23.9,
#     'windchill_f': 75.1,
#     'heatindex_c': 25.7,
#     'heatindex_f': 78.3,
#     'dewpoint_c': 17.9,
#     'dewpoint_f': 64.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.0,
#     'gust_kph': 11.3,
#     'uv': 4.2,
#     'short_rad': 445.6,
#     'diff_rad': 228.34,
#     'dni': 1965.3,
#     'gti': 256.62},
#    {'time_epoch': 1758744000,
#     'time': '2025-09-24 16:00',
#     'temp_c': 23.8,
#     'temp_f': 74.8,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 289,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.9,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 63,
#     'cloud': 33,
#     'feelslike_c': 25.5,
#     'feelslike_f': 78.0,
#     'windchill_c': 23.8,
#     'windchill_f': 74.8,
#     'heatindex_c': 25.5,
#     'heatindex_f': 78.0,
#     'dewpoint_c': 17.6,
#     'dewpoint_f': 63.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 5.5,
#     'gust_kph': 8.9,
#     'uv': 2.3,
#     'short_rad': 360.44,
#     'diff_rad': 191.5,
#     'dni': 0.0,
#     'gti': 178.68},
#    {'time_epoch': 1758747600,
#     'time': '2025-09-24 17:00',
#     'temp_c': 24.0,
#     'temp_f': 75.2,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 289,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.9,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 72,
#     'cloud': 96,
#     'feelslike_c': 25.7,
#     'feelslike_f': 78.2,
#     'windchill_c': 24.0,
#     'windchill_f': 75.2,
#     'heatindex_c': 25.7,
#     'heatindex_f': 78.2,
#     'dewpoint_c': 18.2,
#     'dewpoint_f': 64.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.3,
#     'gust_kph': 6.9,
#     'uv': 1.9,
#     'short_rad': 380.64,
#     'diff_rad': 188.71,
#     'dni': 0.0,
#     'gti': 176.63},
#    {'time_epoch': 1758751200,
#     'time': '2025-09-24 18:00',
#     'temp_c': 23.9,
#     'temp_f': 75.0,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 1.3,
#     'wind_kph': 2.2,
#     'wind_degree': 42,
#     'wind_dir': 'NE',
#     'pressure_mb': 1012.0,
#     'pressure_in': 29.9,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 70,
#     'cloud': 100,
#     'feelslike_c': 25.7,
#     'feelslike_f': 78.2,
#     'windchill_c': 23.9,
#     'windchill_f': 75.0,
#     'heatindex_c': 25.7,
#     'heatindex_f': 78.2,
#     'dewpoint_c': 18.3,
#     'dewpoint_f': 65.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 1.9,
#     'gust_kph': 3.1,
#     'uv': 0.6,
#     'short_rad': 320.94,
#     'diff_rad': 160.5,
#     'dni': 0.0,
#     'gti': 150.16},
#    {'time_epoch': 1758754800,
#     'time': '2025-09-24 19:00',
#     'temp_c': 23.3,
#     'temp_f': 73.9,
#     'is_day': 1,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#      'code': 1009},
#     'wind_mph': 2.0,
#     'wind_kph': 3.2,
#     'wind_degree': 64,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.91,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 75,
#     'cloud': 100,
#     'feelslike_c': 25.3,
#     'feelslike_f': 77.5,
#     'windchill_c': 23.3,
#     'windchill_f': 73.9,
#     'heatindex_c': 25.3,
#     'heatindex_f': 77.5,
#     'dewpoint_c': 19.1,
#     'dewpoint_f': 66.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.4,
#     'gust_kph': 5.5,
#     'uv': 0.1,
#     'short_rad': 268.42,
#     'diff_rad': 135.02,
#     'dni': 0.0,
#     'gti': 126.28},
#    {'time_epoch': 1758758400,
#     'time': '2025-09-24 20:00',
#     'temp_c': 22.7,
#     'temp_f': 72.9,
#     'is_day': 0,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 0.7,
#     'wind_kph': 1.1,
#     'wind_degree': 64,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.92,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 80,
#     'cloud': 99,
#     'feelslike_c': 24.9,
#     'feelslike_f': 76.9,
#     'windchill_c': 22.7,
#     'windchill_f': 72.9,
#     'heatindex_c': 24.9,
#     'heatindex_f': 76.9,
#     'dewpoint_c': 19.0,
#     'dewpoint_f': 66.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 9.0,
#     'vis_miles': 5.0,
#     'gust_mph': 1.3,
#     'gust_kph': 2.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758762000,
#     'time': '2025-09-24 21:00',
#     'temp_c': 22.3,
#     'temp_f': 72.2,
#     'is_day': 0,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 78,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.92,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 84,
#     'cloud': 100,
#     'feelslike_c': 24.7,
#     'feelslike_f': 76.5,
#     'windchill_c': 22.3,
#     'windchill_f': 72.2,
#     'heatindex_c': 24.7,
#     'heatindex_f': 76.5,
#     'dewpoint_c': 19.3,
#     'dewpoint_f': 66.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.3,
#     'gust_kph': 13.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758765600,
#     'time': '2025-09-24 22:00',
#     'temp_c': 21.7,
#     'temp_f': 71.0,
#     'is_day': 0,
#     'condition': {'text': 'Overcast ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/122.png',
#      'code': 1009},
#     'wind_mph': 1.3,
#     'wind_kph': 2.2,
#     'wind_degree': 121,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1013.0,
#     'pressure_in': 29.93,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 86,
#     'cloud': 100,
#     'feelslike_c': 21.7,
#     'feelslike_f': 71.0,
#     'windchill_c': 21.7,
#     'windchill_f': 71.0,
#     'heatindex_c': 22.8,
#     'heatindex_f': 73.1,
#     'dewpoint_c': 19.5,
#     'dewpoint_f': 67.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 2.0,
#     'vis_miles': 1.0,
#     'gust_mph': 2.5,
#     'gust_kph': 4.0,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758769200,
#     'time': '2025-09-24 23:00',
#     'temp_c': 21.2,
#     'temp_f': 70.1,
#     'is_day': 0,
#     'condition': {'text': 'Light rain shower',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#      'code': 1240},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 131,
#     'wind_dir': 'SE',
#     'pressure_mb': 1012.0,
#     'pressure_in': 29.87,
#     'precip_mm': 0.48,
#     'precip_in': 0.02,
#     'snow_cm': 0.0,
#     'humidity': 96,
#     'cloud': 100,
#     'feelslike_c': 21.2,
#     'feelslike_f': 70.1,
#     'windchill_c': 21.2,
#     'windchill_f': 70.1,
#     'heatindex_c': 22.4,
#     'heatindex_f': 72.3,
#     'dewpoint_c': 20.4,
#     'dewpoint_f': 68.7,
#     'will_it_rain': 1,
#     'chance_of_rain': 100,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.7,
#     'gust_kph': 9.2,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0}]},
#  {'date': '2025-09-25',
#   'date_epoch': 1758758400,
#   'day': {'maxtemp_c': 21.9,
#    'maxtemp_f': 71.4,
#    'mintemp_c': 18.3,
#    'mintemp_f': 64.9,
#    'avgtemp_c': 20.0,
#    'avgtemp_f': 68.0,
#    'maxwind_mph': 5.4,
#    'maxwind_kph': 8.6,
#    'totalprecip_mm': 7.94,
#    'totalprecip_in': 0.31,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 7.7,
#    'avgvis_miles': 4.0,
#    'avghumidity': 91,
#    'daily_will_it_rain': 1,
#    'daily_chance_of_rain': 87,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Moderate rain',
# ...
#     'wind_degree': 30,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.11,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 74,
#     'cloud': 2,
#     'feelslike_c': 16.7,
#     'feelslike_f': 62.1,
#     'windchill_c': 16.7,
#     'windchill_f': 62.1,
#     'heatindex_c': 16.7,
#     'heatindex_f': 62.1,
#     'dewpoint_c': 12.0,
#     'dewpoint_f': 53.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.8,
#     'gust_kph': 12.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1759147200,
#     'time': '2025-09-29 08:00',
#     'temp_c': 17.8,
#     'temp_f': 64.0,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 29,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.12,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 76,
#     'cloud': 2,
#     'feelslike_c': 17.7,
#     'feelslike_f': 63.9,
#     'windchill_c': 17.7,
#     'windchill_f': 63.9,
#     'heatindex_c': 18.0,
#     'heatindex_f': 64.4,
#     'dewpoint_c': 12.0,
#     'dewpoint_f': 53.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.2,
#     'gust_kph': 13.2,
#     'uv': 5.0,
#     'short_rad': 0.59,
#     'diff_rad': 0.3,
#     'dni': 0.43,
#     'gti': 0.35},
#    {'time_epoch': 1759150800,
#     'time': '2025-09-29 09:00',
#     'temp_c': 19.5,
#     'temp_f': 67.1,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.7,
#     'wind_kph': 7.6,
#     'wind_degree': 38,
#     'wind_dir': 'NE',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.12,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 69,
#     'cloud': 3,
#     'feelslike_c': 19.5,
#     'feelslike_f': 67.1,
#     'windchill_c': 19.5,
#     'windchill_f': 67.1,
#     'heatindex_c': 20.1,
#     'heatindex_f': 68.2,
#     'dewpoint_c': 12.7,
#     'dewpoint_f': 54.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.8,
#     'gust_kph': 12.6,
#     'uv': 5.0,
#     'short_rad': 146.3,
#     'diff_rad': 32.86,
#     'dni': 162.04,
#     'gti': 60.22},
#    {'time_epoch': 1759154400,
#     'time': '2025-09-29 10:00',
#     'temp_c': 21.6,
#     'temp_f': 70.9,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 5.4,
#     'wind_kph': 8.6,
#     'wind_degree': 47,
#     'wind_dir': 'NE',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.12,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 62,
#     'cloud': 4,
#     'feelslike_c': 21.6,
#     'feelslike_f': 70.8,
#     'windchill_c': 21.6,
#     'windchill_f': 70.8,
#     'heatindex_c': 22.6,
#     'heatindex_f': 72.7,
#     'dewpoint_c': 13.4,
#     'dewpoint_f': 56.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 6.0,
#     'short_rad': 219.15,
#     'diff_rad': 49.14,
#     'dni': 242.85,
#     'gti': 90.16},
#    {'time_epoch': 1759158000,
#     'time': '2025-09-29 11:00',
#     'temp_c': 23.4,
#     'temp_f': 74.2,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 6.0,
#     'wind_kph': 9.7,
#     'wind_degree': 56,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1020.0,
#     'pressure_in': 30.12,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 55,
#     'cloud': 5,
#     'feelslike_c': 24.5,
#     'feelslike_f': 76.0,
#     'windchill_c': 23.4,
#     'windchill_f': 74.2,
#     'heatindex_c': 24.5,
#     'heatindex_f': 76.0,
#     'dewpoint_c': 14.0,
#     'dewpoint_f': 57.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.0,
#     'gust_kph': 11.2,
#     'uv': 6.0,
#     'short_rad': 292.0,
#     'diff_rad': 65.42,
#     'dni': 323.66,
#     'gti': 120.1},
#    {'time_epoch': 1759161600,
#     'time': '2025-09-29 12:00',
#     'temp_c': 25.2,
#     'temp_f': 77.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 57,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.1,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 51,
#     'cloud': 5,
#     'feelslike_c': 25.9,
#     'feelslike_f': 78.7,
#     'windchill_c': 25.2,
#     'windchill_f': 77.3,
#     'heatindex_c': 25.9,
#     'heatindex_f': 78.7,
#     'dewpoint_c': 14.2,
#     'dewpoint_f': 57.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 7.0,
#     'short_rad': 391.54,
#     'diff_rad': 75.48,
#     'dni': 883.7,
#     'gti': 136.75},
#    {'time_epoch': 1759165200,
#     'time': '2025-09-29 13:00',
#     'temp_c': 26.8,
#     'temp_f': 80.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 6.7,
#     'wind_kph': 10.8,
#     'wind_degree': 58,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.09,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 47,
#     'cloud': 5,
#     'feelslike_c': 27.2,
#     'feelslike_f': 81.0,
#     'windchill_c': 26.8,
#     'windchill_f': 80.3,
#     'heatindex_c': 27.2,
#     'heatindex_f': 81.0,
#     'dewpoint_c': 14.4,
#     'dewpoint_f': 57.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.6,
#     'gust_kph': 12.2,
#     'uv': 7.0,
#     'short_rad': 441.32,
#     'diff_rad': 80.5,
#     'dni': 1163.72,
#     'gti': 145.08},
#    {'time_epoch': 1759168800,
#     'time': '2025-09-29 14:00',
#     'temp_c': 27.8,
#     'temp_f': 82.1,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 6.9,
#     'wind_kph': 11.2,
#     'wind_degree': 59,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 43,
#     'cloud': 5,
#     'feelslike_c': 28.0,
#     'feelslike_f': 82.4,
#     'windchill_c': 27.8,
#     'windchill_f': 82.0,
#     'heatindex_c': 28.0,
#     'heatindex_f': 82.4,
#     'dewpoint_c': 14.6,
#     'dewpoint_f': 58.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.0,
#     'gust_kph': 12.9,
#     'uv': 7.0,
#     'short_rad': 491.09,
#     'diff_rad': 85.53,
#     'dni': 1443.74,
#     'gti': 153.4},
#    {'time_epoch': 1759172400,
#     'time': '2025-09-29 15:00',
#     'temp_c': 28.4,
#     'temp_f': 83.1,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.9,
#     'wind_kph': 11.2,
#     'wind_degree': 57,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 42,
#     'cloud': 19,
#     'feelslike_c': 28.5,
#     'feelslike_f': 83.3,
#     'windchill_c': 28.5,
#     'windchill_f': 83.2,
#     'heatindex_c': 28.5,
#     'heatindex_f': 83.3,
#     'dewpoint_c': 14.4,
#     'dewpoint_f': 57.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.1,
#     'gust_kph': 13.0,
#     'uv': 7.0,
#     'short_rad': 549.29,
#     'diff_rad': 95.77,
#     'dni': 721.87,
#     'gti': 130.54},
#    {'time_epoch': 1759176000,
#     'time': '2025-09-29 16:00',
#     'temp_c': 28.9,
#     'temp_f': 84.0,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 6.7,
#     'wind_kph': 10.8,
#     'wind_degree': 54,
#     'wind_dir': 'NE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.03,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 41,
#     'cloud': 32,
#     'feelslike_c': 28.9,
#     'feelslike_f': 84.0,
#     'windchill_c': 28.9,
#     'windchill_f': 84.0,
#     'heatindex_c': 28.9,
#     'heatindex_f': 84.0,
#     'dewpoint_c': 14.3,
#     'dewpoint_f': 57.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.1,
#     'gust_kph': 13.0,
#     'uv': 7.0,
#     'short_rad': 578.4,
#     'diff_rad': 100.89,
#     'dni': 360.94,
#     'gti': 119.1},
#    {'time_epoch': 1759179600,
#     'time': '2025-09-29 17:00',
#     'temp_c': 28.2,
#     'temp_f': 82.8,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.7,
#     'wind_kph': 10.8,
#     'wind_degree': 52,
#     'wind_dir': 'NE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.02,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 40,
#     'cloud': 46,
#     'feelslike_c': 28.4,
#     'feelslike_f': 83.2,
#     'windchill_c': 28.3,
#     'windchill_f': 82.9,
#     'heatindex_c': 28.4,
#     'heatindex_f': 83.2,
#     'dewpoint_c': 14.2,
#     'dewpoint_f': 57.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.1,
#     'gust_kph': 13.0,
#     'uv': 7.0,
#     'short_rad': 607.5,
#     'diff_rad': 106.01,
#     'dni': 0.0,
#     'gti': 107.67},
#    {'time_epoch': 1759183200,
#     'time': '2025-09-29 18:00',
#     'temp_c': 27.0,
#     'temp_f': 80.6,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 6.3,
#     'wind_kph': 10.1,
#     'wind_degree': 43,
#     'wind_dir': 'NE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.03,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 44,
#     'cloud': 46,
#     'feelslike_c': 27.6,
#     'feelslike_f': 81.6,
#     'windchill_c': 27.0,
#     'windchill_f': 80.6,
#     'heatindex_c': 27.6,
#     'heatindex_f': 81.6,
#     'dewpoint_c': 14.2,
#     'dewpoint_f': 57.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.9,
#     'gust_kph': 14.4,
#     'uv': 7.0,
#     'short_rad': 492.12,
#     'diff_rad': 89.81,
#     'dni': 0.0,
#     'gti': 90.73},
#    {'time_epoch': 1759186800,
#     'time': '2025-09-29 19:00',
#     'temp_c': 25.5,
#     'temp_f': 78.0,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 5.6,
#     'wind_kph': 9.0,
#     'wind_degree': 34,
#     'wind_dir': 'NE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.03,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 49,
#     'cloud': 46,
#     'feelslike_c': 26.5,
#     'feelslike_f': 79.6,
#     'windchill_c': 25.6,
#     'windchill_f': 78.0,
#     'heatindex_c': 26.5,
#     'heatindex_f': 79.6,
#     'dewpoint_c': 14.1,
#     'dewpoint_f': 57.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.8,
#     'gust_kph': 15.8,
#     'uv': 7.0,
#     'short_rad': 434.43,
#     'diff_rad': 81.71,
#     'dni': 0.0,
#     'gti': 82.26},
#    {'time_epoch': 1759190400,
#     'time': '2025-09-29 20:00',
#     'temp_c': 24.7,
#     'temp_f': 76.4,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 5.1,
#     'wind_kph': 8.3,
#     'wind_degree': 26,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 53,
#     'cloud': 46,
#     'feelslike_c': 25.8,
#     'feelslike_f': 78.5,
#     'windchill_c': 24.7,
#     'windchill_f': 76.4,
#     'heatindex_c': 25.8,
#     'heatindex_f': 78.5,
#     'dewpoint_c': 14.1,
#     'dewpoint_f': 57.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 10.8,
#     'gust_kph': 17.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1759194000,
#     'time': '2025-09-29 21:00',
#     'temp_c': 24.1,
#     'temp_f': 75.4,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 4.9,
#     'wind_kph': 7.9,
#     'wind_degree': 33,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 54,
#     'cloud': 46,
#     'feelslike_c': 25.5,
#     'feelslike_f': 77.8,
#     'windchill_c': 24.1,
#     'windchill_f': 75.4,
#     'heatindex_c': 25.5,
#     'heatindex_f': 77.8,
#     'dewpoint_c': 14.0,
#     'dewpoint_f': 57.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.8,
#     'gust_kph': 15.8,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1759197600,
#     'time': '2025-09-29 22:00',
#     'temp_c': 23.7,
#     'temp_f': 74.6,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 40,
#     'wind_dir': 'NE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 55,
#     'cloud': 45,
#     'feelslike_c': 25.2,
#     'feelslike_f': 77.4,
#     'windchill_c': 23.7,
#     'windchill_f': 74.6,
#     'heatindex_c': 25.2,
#     'heatindex_f': 77.4,
#     'dewpoint_c': 13.9,
#     'dewpoint_f': 57.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.2,
#     'gust_kph': 14.8,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1759201200,
#     'time': '2025-09-29 23:00',
#     'temp_c': 23.3,
#     'temp_f': 73.9,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 47,
#     'wind_dir': 'NE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.06,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 56,
#     'cloud': 44,
#     'feelslike_c': 25.0,
#     'feelslike_f': 77.0,
#     'windchill_c': 23.3,
#     'windchill_f': 73.9,
#     'heatindex_c': 25.0,
#     'heatindex_f': 77.0,
#     'dewpoint_c': 13.9,
#     'dewpoint_f': 57.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.2,
#     'gust_kph': 13.2,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0}]}]

# %%
# Get a forecast for 7 days
def get_forecast(city, api_key):
    forecast_url= f"{baseurl}/forecast.json?key={api_key}&q={city}&days=7"
    forecast_response = requests.get(forecast_url)
    forecast_data = forecast_response.json()
    forecast = forecast_data['forecast']['forecastday']
    forecast_7_days = []
    for day in forecast:
        date_obj = datetime.strptime(day['date'], '%Y-%m-%d')
        formatted_date = date_obj.strftime('%A, %B %d')
        forecast_7_days.append(f"{formatted_date}: High {day['day']['maxtemp_f']}F, Low{day['day']['mintemp_f']}F - {day['day']['condition']['text']}")
    return forecast_7_days

result = get_forecast(city, api_key)

for day in result:
    print(day)
# Out:
# Tuesday, September 23: High 85.5F, Low68.0F - Partly Cloudy
# Wednesday, September 24: High 77.0F, Low69.7F - Patchy rain nearby
# Thursday, September 25: High 71.4F, Low64.9F - Moderate rain
# Friday, September 26: High 75.7F, Low62.1F - Fog
# Saturday, September 27: High 80.1F, Low62.1F - Sunny
# Sunday, September 28: High 84.1F, Low60.1F - Sunny
# Monday, September 29: High 84.8F, Low61.4F - Sunny

# %%
# forecast_7_days_summary 

forecast_7_days_summary = []
for day in forecast:
    forecast_7_days_summary.append(f"{day['date']}:High{day['day']['maxtemp_f']} F, Low{day['day']['mintemp_f']} F - {day['day']['condition']['text']}")

forecast_7_days_summary
# Out:
# ['2025-09-23:High85.5 F, Low68.0 F - Partly Cloudy ',
#  '2025-09-24:High77.0 F, Low69.7 F - Patchy rain nearby',
#  '2025-09-25:High71.4 F, Low64.9 F - Moderate rain',
#  '2025-09-26:High75.7 F, Low62.1 F - Fog',
#  '2025-09-27:High80.1 F, Low62.1 F - Sunny',
#  '2025-09-28:High84.1 F, Low60.1 F - Sunny',
#  '2025-09-29:High84.8 F, Low61.4 F - Sunny']

# %%
#get some astronomical data

def get_astronomy_data(city, api_key):
    today = pd.Timestamp.now().strftime("%Y-%m-%d")
    response = requests.get(f"{baseurl}/astronomy.json?key={api_key}&q={city}&dt={today}")
    astronomy_data = response.json()
    astro = astronomy_data['astronomy']['astro']
    print(f"Sunrise: {astro['sunrise']}")
    print(f"Sunset: {astro['sunset']}")
    print(f"Moonrise: {astro['moonrise']}")
    print(f"Moonset: {astro['moonset']}")  
    print(f"Moon Phase: {astro['moon_phase']}") 

prediction = get_astronomy_data(city, api_key)
# Out:
# Sunrise: 07:32 AM
# Sunset: 07:38 PM
# Moonrise: 09:17 AM
# Moonset: 08:18 PM
# Moon Phase: Waxing Crescent

# %%
# Getting the future forecast 

def get_future_forecast(city, api_key):
    future_forecast_url = f"{baseurl}/future.json?key={api_key}&q={city}&dt=2025-10-20"
    future_forecast_response = requests.get(future_forecast_url)
    future_data = future_forecast_response.json()
    future = future_data['forecast']['forecastday'][0] # getting the forecast day of the first day of the list
    hours = future['hour']

    print(f'Date: {future['date']}')

    for hour_data in hours:
        print(f'Time: {hour_data["time"]}, Temp: {hour_data["temp_c"]}°C')

        weather_data=[]
        dict_time = {
            'city': city,
            'date': future['date'],  # Usamos la fecha del día
            'time': hour_data['time'].split()[1],  # Solo la hora (ej: "12:00")
            'temperature_c': hour_data['temp_c'],
            'condition': hour_data['condition']['text']
        }
        weather_data.append(dict_time)

        
    weather_df = pd.DataFrame(weather_data) # Save as Data Frame
    weather_df.to_csv(r'C:\Users\Code\Desktop\Estudio\Projects\Weather_API_Project/weather_df.csv', index=False) # Saving into a csv file
    

    return weather_df

# %%
resultado = get_future_forecast(city, api_key)

print(f'El resultado es: {resultado}')

future_weather = get_future_forecast(city, api_key)
# Out:
# Date: 2025-10-20
# Time: 2025-10-20 00:00, Temp: 10.4°C
# Time: 2025-10-20 02:00, Temp: 9.9°C
# Time: 2025-10-20 04:00, Temp: 9.3°C
# Time: 2025-10-20 08:00, Temp: 10.6°C
# Time: 2025-10-20 09:00, Temp: 12.2°C
# Time: 2025-10-20 11:00, Temp: 15.7°C
# Time: 2025-10-20 12:00, Temp: 17.1°C
# Time: 2025-10-20 16:00, Temp: 17.6°C
# Time: 2025-10-20 22:00, Temp: 11.6°C
# Time: 2025-10-20 01:00, Temp: 10.2°C
# Time: 2025-10-20 07:00, Temp: 9.7°C
# Time: 2025-10-20 13:00, Temp: 17.6°C
# Time: 2025-10-20 14:00, Temp: 18.0°C
# Time: 2025-10-20 18:00, Temp: 14.8°C
# Time: 2025-10-20 21:00, Temp: 12.0°C
# Time: 2025-10-20 03:00, Temp: 9.6°C
# Time: 2025-10-20 05:00, Temp: 9.2°C
# Time: 2025-10-20 06:00, Temp: 8.9°C
# Time: 2025-10-20 10:00, Temp: 14.0°C
# Time: 2025-10-20 15:00, Temp: 18.3°C
# Time: 2025-10-20 17:00, Temp: 16.5°C
# Time: 2025-10-20 19:00, Temp: 13.7°C
# Time: 2025-10-20 20:00, Temp: 12.7°C
# Time: 2025-10-20 23:00, Temp: 11.2°C
# El resultado es:          city        date   time  temperature_c             condition
# 0  Louisville  2025-10-20  23:00           11.2  Patchy rain possible
# Date: 2025-10-20
# Time: 2025-10-20 00:00, Temp: 10.4°C
# Time: 2025-10-20 02:00, Temp: 9.9°C
# Time: 2025-10-20 04:00, Temp: 9.3°C
# Time: 2025-10-20 08:00, Temp: 10.6°C
# Time: 2025-10-20 09:00, Temp: 12.2°C
# Time: 2025-10-20 11:00, Temp: 15.7°C
# Time: 2025-10-20 12:00, Temp: 17.1°C
# Time: 2025-10-20 16:00, Temp: 17.6°C
# Time: 2025-10-20 22:00, Temp: 11.6°C
# Time: 2025-10-20 01:00, Temp: 10.2°C
# Time: 2025-10-20 07:00, Temp: 9.7°C
# Time: 2025-10-20 13:00, Temp: 17.6°C
# Time: 2025-10-20 14:00, Temp: 18.0°C
# Time: 2025-10-20 18:00, Temp: 14.8°C
# Time: 2025-10-20 21:00, Temp: 12.0°C
# Time: 2025-10-20 03:00, Temp: 9.6°C
# Time: 2025-10-20 05:00, Temp: 9.2°C
# Time: 2025-10-20 06:00, Temp: 8.9°C
# Time: 2025-10-20 10:00, Temp: 14.0°C
# Time: 2025-10-20 15:00, Temp: 18.3°C
# Time: 2025-10-20 17:00, Temp: 16.5°C
# Time: 2025-10-20 19:00, Temp: 13.7°C
# Time: 2025-10-20 20:00, Temp: 12.7°C
# Time: 2025-10-20 23:00, Temp: 11.2°C
